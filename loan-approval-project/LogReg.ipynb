# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("FinalData.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area',
#        'Loan_Status (Approved)'],
#       dtype='object')

# %%
'''
Target : Loan_Status (Approved)
    
   1. Loan_Amount_Term has very low correlation with Target
        Better to remove 
   2. LoanAmounnt cannot be remove bcz it not has correlation with Target with with others 
   3. CoapplicantIncome also should not to remove 

'''
data.drop(["Loan_Amount_Term",'Unnamed: 0'],axis=1,inplace=True)

# %%
data.corr()
# Out:
#                           Gender   Married  Dependents  Education  \
# Gender                  1.000000  0.349424    0.213867  -0.059245
# Married                 0.349424  1.000000    0.372864  -0.001652
# Dependents              0.213867  0.372864    1.000000  -0.030080
# Education              -0.059245 -0.001652   -0.030080   1.000000
# Self_Employed          -0.002761  0.015674    0.040018   0.005085
# ApplicantIncome         0.032644  0.036717    0.137604   0.131172
# LoanAmount              0.098975  0.183442    0.172061   0.172780
# Credit_History          0.022447  0.029095   -0.032292   0.056656
# Property_Area          -0.094940 -0.008139   -0.023588   0.007953
# Loan_Status (Approved)  0.064504  0.112321    0.031600   0.068437
#
#                         Self_Employed  ApplicantIncome  LoanAmount  \
# Gender                      -0.002761         0.032644    0.098975
# Married                      0.015674         0.036717    0.183442
# Dependents                   0.040018         0.137604    0.172061
# Education                    0.005085         0.131172    0.172780
# Self_Employed                1.000000         0.170785    0.120389
# ApplicantIncome              0.170785         1.000000    0.495310
# LoanAmount                   0.120389         0.495310    1.000000
# Credit_History              -0.023568        -0.056152   -0.040773
# Property_Area                0.009830         0.025068    0.062430
# Loan_Status (Approved)      -0.034715        -0.043152   -0.071753
#
#                         Credit_History  Property_Area  Loan_Status (Approved)
# Gender                        0.022447      -0.094940                0.064504
# Married                       0.029095      -0.008139                0.112321
# Dependents                   -0.032292      -0.023588                0.031600
# Education                     0.056656       0.007953                0.068437
# Self_Employed                -0.023568       0.009830               -0.034715
# ApplicantIncome              -0.056152       0.025068               -0.043152
# LoanAmount                   -0.040773       0.062430               -0.071753
# Credit_History                1.000000       0.042091                0.529390
# Property_Area                 0.042091       1.000000                0.121813
# Loan_Status (Approved)        0.529390       0.121813                1.000000

# %%
## Step 1 Creating independent and dependent variable.

x = data[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Credit_History', 'Property_Area']]





y = data['Loan_Status (Approved)']

# %%
data['Loan_Status (Approved)'].value_counts() # data is not balanced
# Out:
# Loan_Status (Approved)
# 1    332
# 0    148
# Name: count, dtype: int64

# %% [markdown]
# ## balancing data using SMOTE

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_res,y_res = sm.fit_resample(x,y)

# %%
y_res.value_counts()  # balanced
# Out:
# Loan_Status (Approved)
# 0    332
# 1    332
# Name: count, dtype: int64

# %%
## Step 2 Creating training and testing data.

from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test = tts(x_res,y_res,test_size=0.25,random_state=42)

# %%
## Step 3 Model creation

from sklearn.linear_model import LogisticRegression as LogReg 
model = LogReg()

#  fitting the model
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
## Step 4 Prediction

y_predict = model.predict(x_test)
y_predict.shape
# Out:
# (166,)

# %%
y_predict_proba = model.predict_proba(x_test)
y_predict_proba
# Out:
# array([[0.23302201, 0.76697799],
#        [0.90993238, 0.09006762],
#        [0.28926615, 0.71073385],
#        [0.15061248, 0.84938752],
#        [0.11737086, 0.88262914],
#        [0.27253847, 0.72746153],
#        [0.70781574, 0.29218426],
#        [0.55410291, 0.44589709],
#        [0.9741423 , 0.0258577 ],
#        [0.36874563, 0.63125437],
#        [0.35481028, 0.64518972],
#        [0.15001721, 0.84998279],
#        [0.91582732, 0.08417268],
#        [0.21966359, 0.78033641],
#        [0.16985715, 0.83014285],
#        [0.91434007, 0.08565993],
#        [0.51480781, 0.48519219],
#        [0.10221322, 0.89778678],
#        [0.66160187, 0.33839813],
#        [0.28676003, 0.71323997],
#        [0.51609714, 0.48390286],
#        [0.13259056, 0.86740944],
#        [0.88533294, 0.11466706],
#        [0.18931531, 0.81068469],
#        [0.18775472, 0.81224528],
#        [0.29130469, 0.70869531],
#        [0.28576382, 0.71423618],
#        [0.57632246, 0.42367754],
#        [0.22766175, 0.77233825],
#        [0.91777426, 0.08222574],
#        [0.11086746, 0.88913254],
#        [0.84522553, 0.15477447],
#        [0.06180409, 0.93819591],
#        [0.57344247, 0.42655753],
#        [0.19093592, 0.80906408],
#        [0.7929837 , 0.2070163 ],
#        [0.36486231, 0.63513769],
#        [0.96726471, 0.03273529],
#        [0.8274683 , 0.1725317 ],
#        [0.15131544, 0.84868456],
#        [0.91006746, 0.08993254],
#        [0.80036936, 0.19963064],
#        [0.7657594 , 0.2342406 ],
#        [0.88621332, 0.11378668],
#        [0.17475898, 0.82524102],
#        [0.66850526, 0.33149474],
#        [0.56955947, 0.43044053],
#        [0.31916005, 0.68083995],
#        [0.44718862, 0.55281138],
#        [0.52628727, 0.47371273],
#        [0.99729206, 0.00270794],
#        [0.28096248, 0.71903752],
#        [0.93406876, 0.06593124],
#        [0.20738967, 0.79261033],
#        [0.47922026, 0.52077974],
#        [0.52821818, 0.47178182],
#        [0.36929303, 0.63070697],
#        [0.26595229, 0.73404771],
#        [0.95073515, 0.04926485],
#        [0.3359421 , 0.6640579 ],
#        [0.4829276 , 0.5170724 ],
#        [0.23308801, 0.76691199],
#        [0.37670401, 0.62329599],
#        [0.70257505, 0.29742495],
#        [0.64453251, 0.35546749],
#        [0.93860941, 0.06139059],
#        [0.31223964, 0.68776036],
#        [0.89867783, 0.10132217],
#        [0.24753809, 0.75246191],
#        [0.11103722, 0.88896278],
#        [0.21611687, 0.78388313],
#        [0.5224281 , 0.4775719 ],
#        [0.92687706, 0.07312294],
#        [0.72361262, 0.27638738]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,classification_report,f1_score

# %%
confusion_matrix (y_test,y_predict)
# Out:
# array([[59, 25],
#        [18, 64]], dtype=int64)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7409638554216867

# %%
print(recall_score(y_test,y_predict))
# Out:
# 0.7804878048780488

# %%
print(precision_score(y_test,y_predict))
# Out:
# 0.7191011235955056

# %%
print(f1_score(y_test,y_predict))
# Out:
# 0.7485380116959064

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73        84
#            1       0.72      0.78      0.75        82
#
#     accuracy                           0.74       166
#    macro avg       0.74      0.74      0.74       166
# weighted avg       0.74      0.74      0.74       166

# %% [markdown]
# Class 0:
#
# Precision is good (0.80), but recall is lower (0.70).
#
# It means your model correctly identifies most class 0, but misses some.
#
# Class 1:
#
# Recall is high (0.82), so it's catching most positives.
#
# Precision is 0.73, meaning it's okay but has some false positives.
#
# ✅ Overall Accuracy:
# Accuracy = 0.76 → Your model is correct 76% of the time.

# %% [markdown]
# ## Overall Accuracy: 0.76 → The model correctly predicted 76% of the cases
